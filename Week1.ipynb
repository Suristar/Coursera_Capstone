# %% [markdown]
# This notebook will be mainly used for capstone project

# %%
import pandas as pd

# %%
import numpy as np

# %%
print(Hello Capstone Project Course!)
# Out:
#   File "<ipython-input-4-9c6278dcfca8>", line 1
#     print(Hello Capstone Project Course/!)
#                        ^
# SyntaxError: invalid syntax
