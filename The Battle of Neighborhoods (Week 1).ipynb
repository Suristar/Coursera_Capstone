# %% [markdown]
# Introduction

# %% [markdown]
# This is about finding the best neighborhood suitable in Toronto for a new restaurant, making sure that there are not many similar restaurants in the area.

# %% [markdown]
# Audience: could be anyone with hoping to open a new restaurant. This data will help them

# %% [markdown]
# Data

# %% [markdown]
# The data i am using is from wikipedia. The data we used for previous assignment where we had the zip codes. Then i will use foursquare to get the restaurants at those neighborhoods.
